# %%
from figure_builder import plot_3D
from planning_creator_multi_obj import *

# %%
grid, X_grid, Y_grid = surface_paretto()
# Out:
# Set parameter Username
# Academic license - for non-commercial use only - expires 2023-12-10
# Gurobi Optimizer version 10.0.0 build v10.0.0rc2 (win64)
#
# CPU model: Intel(R) Core(TM) i7-1065G7 CPU @ 1.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 442 rows, 329 columns and 1916 nonzeros
# Model fingerprint: 0x6126a823
# Model has 41 general constraints
# Variable types: 0 continuous, 329 integer (270 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 5e+00]
#   Objective range  [3e+00, 2e+01]
#   Bounds range     [1e+00, 1e+02]
#   RHS range        [1e+00, 5e+00]
#   GenCon const rng [1e+00, 1e+00]
# Presolve removed 359 rows and 203 columns
# Presolve time: 0.02s
# Presolved: 83 rows, 126 columns, 548 nonzeros
# Variable types: 0 continuous, 126 integer (109 binary)
# Found heuristic solution: objective 10.0000000
#
# Root relaxation: objective 6.207491e+01, 136 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   62.07491    0   48   10.00000   62.07491   521%     -    0s
# H    0     0                      12.0000000   62.07491   417%     -    0s
# H    0     0                      22.0000000   62.07491   182%     -    0s
# H    0     0                      32.0000000   51.92713  62.3%     -    0s
#      0     0   45.00030    0   54   32.00000   45.00030  40.6%     -    0s
# H    0     0                      35.0000000   45.00030  28.6%     -    0s
#      0     0   42.00000    0   52   35.00000   42.00000  20.0%     -    0s
#      0     0   42.00000    0   51   35.00000   42.00000  20.0%     -    0s
# H    0     0                      40.0000000   42.00000  5.00%     -    0s
#
# Cutting planes:
#   Learned: 1
#   Gomory: 34
#   Cover: 14
#   Implied bound: 2
#   Clique: 7
#   MIR: 9
#   GUB cover: 1
#   Zero half: 1
#   RLT: 2
#   Relax-and-lift: 4
#
# Explored 1 nodes (293 simplex iterations) in 0.12 seconds (0.01 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 6: 40 35 32 ... 10
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.000000000000e+01, best bound 4.000000000000e+01, gap 0.0000%
# 1
# 1
# 40.0
# ____
# Gurobi Optimizer version 10.0.0 build v10.0.0rc2 (win64)
#
# CPU model: Intel(R) Core(TM) i7-1065G7 CPU @ 1.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 442 rows, 329 columns and 1916 nonzeros
# Model fingerprint: 0x3f7e7d70
# Model has 41 general constraints
# Variable types: 0 continuous, 329 integer (270 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 5e+00]
#   Objective range  [3e+00, 2e+01]
#   Bounds range     [1e+00, 1e+02]
#   RHS range        [1e+00, 5e+00]
#   GenCon const rng [1e+00, 1e+00]
# Presolve removed 351 rows and 190 columns
# Presolve time: 0.01s
# Presolved: 91 rows, 139 columns, 584 nonzeros
# Variable types: 0 continuous, 139 integer (117 binary)
# Found heuristic solution: objective -6.0000000
# Found heuristic solution: objective -0.0000000
# Found heuristic solution: objective 10.0000000
#
# Root relaxation: objective 7.358333e+01, 134 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   73.58333    0   50   10.00000   73.58333   636%     -    0s
# H    0     0                      15.0000000   73.58333   391%     -    0s
# H    0     0                      42.0000000   73.58333  75.2%     -    0s
# H    0     0                      52.0000000   73.58333  41.5%     -    0s
# H    0     0                      60.0000000   66.08140  10.1%     -    0s
#      0     0   66.08140    0   66   60.00000   66.08140  10.1%     -    0s
#      0     0   66.08140    0   70   60.00000   66.08140  10.1%     -    0s
#      0     0   65.41709    0   66   60.00000   65.41709  9.03%     -    0s
#      0     0   65.41709    0   68   60.00000   65.41709  9.03%     -    0s
#      0     0   65.00001    0   64   60.00000   65.00001  8.33%     -    0s
#      0     0   65.00001    0   64   60.00000   65.00001  8.33%     -    0s
# H    0     0                      65.0000000   65.00001  0.00%     -    0s
#
# Cutting planes:
#   Gomory: 4
#   Cover: 13
#   Implied bound: 2
#   Clique: 2
#   MIR: 8
#   StrongCG: 1
#   Flow cover: 2
#   Zero half: 11
#   Mod-K: 1
#   RLT: 2
#   Relax-and-lift: 4
#
# Explored 1 nodes (314 simplex iterations) in 0.10 seconds (0.02 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 8: 65 60 52 ... -6
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 6.500000000000e+01, best bound 6.500000000000e+01, gap 0.0000%
# 1
# 2
# 65.0
# ____
# Gurobi Optimizer version 10.0.0 build v10.0.0rc2 (win64)
#
# CPU model: Intel(R) Core(TM) i7-1065G7 CPU @ 1.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 442 rows, 329 columns and 1916 nonzeros
# Model fingerprint: 0x7f0f1aa9
# Model has 41 general constraints
# Variable types: 0 continuous, 329 integer (270 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 5e+00]
#   Objective range  [3e+00, 2e+01]
#   Bounds range     [1e+00, 1e+02]
#   RHS range        [1e+00, 5e+00]
#   GenCon const rng [1e+00, 1e+00]
# Presolve removed 351 rows and 190 columns
# Presolve time: 0.01s
# Presolved: 91 rows, 139 columns, 584 nonzeros
# Variable types: 0 continuous, 139 integer (117 binary)
# Found heuristic solution: objective 4.0000000
#
# Root relaxation: objective 7.366667e+01, 128 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   73.66667    0   49    4.00000   73.66667  1742%     -    0s
# H    0     0                      39.0000000   73.66667  88.9%     -    0s
# H    0     0                      58.0000000   73.66667  27.0%     -    0s
# H    0     0                      64.0000000   71.00000  10.9%     -    0s
#      0     0   71.00000    0   36   64.00000   71.00000  10.9%     -    0s
#      0     0   65.50000    0   35   64.00000   65.50000  2.34%     -    0s
# H    0     0                      65.0000000   65.50000  0.77%     -    0s
#      0     0   65.00000    0   37   65.00000   65.00000  0.00%     -    0s
#
# Cutting planes:
#   Learned: 1
#   Gomory: 2
#   Cover: 8
#   Implied bound: 1
#   Clique: 3
#   MIR: 6
#   GUB cover: 1
#   Zero half: 6
#   Relax-and-lift: 3
#
# Explored 1 nodes (310 simplex iterations) in 0.09 seconds (0.01 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 5: 65 64 58 ... 4
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 6.500000000000e+01, best bound 6.500000000000e+01, gap 0.0000%
# 1
# 3
# 65.0
# ____
# Gurobi Optimizer version 10.0.0 build v10.0.0rc2 (win64)
#
# CPU model: Intel(R) Core(TM) i7-1065G7 CPU @ 1.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 442 rows, 329 columns and 1916 nonzeros
# Model fingerprint: 0x6e1dbd4f
# Model has 41 general constraints
# Variable types: 0 continuous, 329 integer (270 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 5e+00]
#   Objective range  [3e+00, 2e+01]
#   Bounds range     [1e+00, 1e+02]
#   RHS range        [1e+00, 5e+00]
#   GenCon const rng [1e+00, 1e+00]
# Presolve removed 353 rows and 192 columns
# Presolve time: 0.01s
# Presolved: 89 rows, 137 columns, 580 nonzeros
# Variable types: 0 continuous, 137 integer (117 binary)
# Found heuristic solution: objective 4.0000000
#
# Root relaxation: objective 7.366667e+01, 103 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   73.66667    0   26    4.00000   73.66667  1742%     -    0s
# H    0     0                      45.0000000   73.66667  63.7%     -    0s
# H    0     0                      64.0000000   73.66667  15.1%     -    0s
#      0     0   71.00000    0   17   64.00000   71.00000  10.9%     -    0s
# H    0     0                      65.0000000   68.11111  4.79%     -    0s
#      0     0   68.00000    0   45   65.00000   68.00000  4.62%     -    0s
#      0     0   68.00000    0   55   65.00000   68.00000  4.62%     -    0s
#      0     0   68.00000    0   49   65.00000   68.00000  4.62%     -    0s
#      0     0   65.00000    0   21   65.00000   65.00000  0.00%     -    0s
#
# Cutting planes:
#   Gomory: 4
#   Implied bound: 1
#   Clique: 1
#   MIR: 3
#   Zero half: 2
#   Relax-and-lift: 1
#
# Explored 1 nodes (304 simplex iterations) in 0.06 seconds (0.01 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 4: 65 64 45 4
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 6.500000000000e+01, best bound 6.500000000000e+01, gap 0.0000%
# 1
# 4
# 65.0
# ____
# Gurobi Optimizer version 10.0.0 build v10.0.0rc2 (win64)
#
# CPU model: Intel(R) Core(TM) i7-1065G7 CPU @ 1.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 442 rows, 329 columns and 1916 nonzeros
# Model fingerprint: 0x695f8295
# Model has 41 general constraints
# Variable types: 0 continuous, 329 integer (270 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 5e+00]
#   Objective range  [3e+00, 2e+01]
#   Bounds range     [1e+00, 1e+02]
#   RHS range        [1e+00, 5e+00]
#   GenCon const rng [1e+00, 1e+00]
# Presolve removed 362 rows and 206 columns
# Presolve time: 0.01s
# Presolved: 80 rows, 123 columns, 536 nonzeros
# Variable types: 0 continuous, 123 integer (108 binary)
# Found heuristic solution: objective -6.0000000
# Found heuristic solution: objective 4.0000000
#
# Root relaxation: objective 5.866738e+01, 143 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   58.66738    0   45    4.00000   58.66738  1367%     -    0s
# H    0     0                      13.0000000   58.66738   351%     -    0s
# H    0     0                      32.0000000   58.66738  83.3%     -    0s
# H    0     0                      42.0000000   45.34413  7.96%     -    0s
#      0     0   42.00000    0   47   42.00000   42.00000  0.00%     -    0s
#
# Cutting planes:
#   Gomory: 18
#   Cover: 9
#   Implied bound: 1
#   Clique: 18
#   MIR: 4
#   StrongCG: 1
#   Flow cover: 1
#   GUB cover: 2
#   Zero half: 8
#   RLT: 5
#   Relax-and-lift: 4
#
# Explored 1 nodes (266 simplex iterations) in 0.06 seconds (0.01 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 5: 42 32 13 ... -6
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.200000000000e+01, best bound 4.200000000000e+01, gap 0.0000%
# 2
# 1
# 42.0
# ____
# Gurobi Optimizer version 10.0.0 build v10.0.0rc2 (win64)
#
# CPU model: Intel(R) Core(TM) i7-1065G7 CPU @ 1.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 442 rows, 329 columns and 1916 nonzeros
# Model fingerprint: 0xf543ef96
# Model has 41 general constraints
# Variable types: 0 continuous, 329 integer (270 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 5e+00]
#   Objective range  [3e+00, 2e+01]
#   Bounds range     [1e+00, 1e+02]
#   RHS range        [1e+00, 5e+00]
#   GenCon const rng [1e+00, 1e+00]
# Presolve removed 354 rows and 193 columns
# Presolve time: 0.01s
# Presolved: 88 rows, 136 columns, 572 nonzeros
# Variable types: 0 continuous, 136 integer (116 binary)
# Found heuristic solution: objective 4.0000000
#
# Root relaxation: objective 7.200000e+01, 116 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   72.00000    0   31    4.00000   72.00000  1700%     -    0s
# H    0     0                      32.0000000   72.00000   125%     -    0s
# H    0     0                      58.0000000   70.50000  21.6%     -    0s
#      0     0   70.50000    0   55   58.00000   70.50000  21.6%     -    0s
#      0     0   66.50000    0   52   58.00000   66.50000  14.7%     -    0s
# H    0     0                      65.0000000   65.50000  0.77%     -    0s
#      0     0   65.50000    0   57   65.00000   65.50000  0.77%     -    0s
#
# Cutting planes:
#   Gomory: 16
#   Cover: 6
#   Clique: 4
#   MIR: 9
#   StrongCG: 2
#   Flow cover: 1
#   Zero half: 5
#   RLT: 2
#   Relax-and-lift: 4
#
# Explored 1 nodes (291 simplex iterations) in 0.08 seconds (0.01 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 4: 65 58 32 4
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 6.500000000000e+01, best bound 6.500000000000e+01, gap 0.0000%
# 2
# 2
# 65.0
# ____
# Gurobi Optimizer version 10.0.0 build v10.0.0rc2 (win64)
#
# CPU model: Intel(R) Core(TM) i7-1065G7 CPU @ 1.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 442 rows, 329 columns and 1916 nonzeros
# Model fingerprint: 0x9403c147
# Model has 41 general constraints
# Variable types: 0 continuous, 329 integer (270 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 5e+00]
#   Objective range  [3e+00, 2e+01]
#   Bounds range     [1e+00, 1e+02]
#   RHS range        [1e+00, 5e+00]
#   GenCon const rng [1e+00, 1e+00]
# Presolve removed 354 rows and 193 columns
# Presolve time: 0.01s
# Presolved: 88 rows, 136 columns, 572 nonzeros
# Variable types: 0 continuous, 136 integer (116 binary)
# Found heuristic solution: objective -12.0000000
# Found heuristic solution: objective 4.0000000
#
# Root relaxation: objective 7.200000e+01, 106 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   72.00000    0   19    4.00000   72.00000  1700%     -    0s
# H    0     0                      35.0000000   72.00000   106%     -    0s
# H    0     0                      59.0000000   72.00000  22.0%     -    0s
# H    0     0                      62.0000000   71.85714  15.9%     -    0s
#      0     0   71.40000    0   48   62.00000   71.40000  15.2%     -    0s
#      0     0   66.40000    0   45   62.00000   66.40000  7.10%     -    0s
# H    0     0                      65.0000000   65.71429  1.10%     -    0s
#      0     0   65.71429    0   56   65.00000   65.71429  1.10%     -    0s
#
# Cutting planes:
#   Gomory: 12
#   Cover: 7
#   Implied bound: 1
#   Clique: 2
#   MIR: 4
#   Flow cover: 1
#   GUB cover: 1
#   Zero half: 12
#
# Explored 1 nodes (288 simplex iterations) in 0.11 seconds (0.01 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 6: 65 62 59 ... -12
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 6.500000000000e+01, best bound 6.500000000000e+01, gap 0.0000%
# 2
# 3
# 65.0
# ____
# Gurobi Optimizer version 10.0.0 build v10.0.0rc2 (win64)
#
# CPU model: Intel(R) Core(TM) i7-1065G7 CPU @ 1.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 442 rows, 329 columns and 1916 nonzeros
# Model fingerprint: 0xcda96520
# Model has 41 general constraints
# Variable types: 0 continuous, 329 integer (270 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 5e+00]
#   Objective range  [3e+00, 2e+01]
#   Bounds range     [1e+00, 1e+02]
#   RHS range        [1e+00, 5e+00]
#   GenCon const rng [1e+00, 1e+00]
# Presolve removed 356 rows and 195 columns
# Presolve time: 0.01s
# Presolved: 86 rows, 134 columns, 568 nonzeros
# Variable types: 0 continuous, 134 integer (116 binary)
# Found heuristic solution: objective -12.0000000
# Found heuristic solution: objective 4.0000000
#
# Root relaxation: objective 7.200000e+01, 90 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   72.00000    0   16    4.00000   72.00000  1700%     -    0s
# H    0     0                      45.0000000   72.00000  60.0%     -    0s
# H    0     0                      58.0000000   72.00000  24.1%     -    0s
# H    0     0                      59.0000000   72.00000  22.0%     -    0s
# H    0     0                      65.0000000   72.00000  10.8%     -    0s
#      0     0   66.66667    0   21   65.00000   66.66667  2.56%     -    0s
#      0     0     cutoff    0        65.00000   65.00000  0.00%     -    0s
#
# Cutting planes:
#   Gomory: 3
#   Cover: 2
#   Clique: 4
#   MIR: 3
#   Flow cover: 2
#   Zero half: 1
#   Relax-and-lift: 2
#
# Explored 1 nodes (220 simplex iterations) in 0.05 seconds (0.01 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 6: 65 59 58 ... -12
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 6.500000000000e+01, best bound 6.500000000000e+01, gap 0.0000%
# 2
# 4
# 65.0
# ____
# Gurobi Optimizer version 10.0.0 build v10.0.0rc2 (win64)
#
# CPU model: Intel(R) Core(TM) i7-1065G7 CPU @ 1.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 442 rows, 329 columns and 1916 nonzeros
# Model fingerprint: 0x648b9b1d
# Model has 41 general constraints
# Variable types: 0 continuous, 329 integer (270 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 5e+00]
#   Objective range  [3e+00, 2e+01]
#   Bounds range     [1e+00, 1e+02]
#   RHS range        [1e+00, 5e+00]
#   GenCon const rng [1e+00, 1e+00]
# Presolve removed 363 rows and 207 columns
# Presolve time: 0.02s
# Presolved: 79 rows, 122 columns, 525 nonzeros
# Variable types: 0 continuous, 122 integer (107 binary)
# Found heuristic solution: objective 4.0000000
#
# Root relaxation: objective 5.597651e+01, 129 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   55.97651    0   45    4.00000   55.97651  1299%     -    0s
# H    0     0                      14.0000000   55.97651   300%     -    0s
# H    0     0                      29.0000000   55.97651  93.0%     -    0s
# H    0     0                      39.0000000   43.90076  12.6%     -    0s
#      0     0   39.00000    0   42   39.00000   39.00000  0.00%     -    0s
#
# Cutting planes:
#   Gomory: 17
#   Cover: 9
#   Implied bound: 2
#   Clique: 21
#   MIR: 5
#   Flow cover: 1
#   GUB cover: 1
#   Zero half: 9
#   RLT: 5
#   Relax-and-lift: 3
#
# Explored 1 nodes (234 simplex iterations) in 0.07 seconds (0.01 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 4: 39 29 14 4
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.900000000000e+01, best bound 3.900000000000e+01, gap 0.0000%
# 3
# 1
# 39.0
# ____
# Gurobi Optimizer version 10.0.0 build v10.0.0rc2 (win64)
#
# CPU model: Intel(R) Core(TM) i7-1065G7 CPU @ 1.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 442 rows, 329 columns and 1916 nonzeros
# Model fingerprint: 0x97944b3a
# Model has 41 general constraints
# Variable types: 0 continuous, 329 integer (270 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 5e+00]
#   Objective range  [3e+00, 2e+01]
#   Bounds range     [1e+00, 1e+02]
#   RHS range        [1e+00, 5e+00]
#   GenCon const rng [1e+00, 1e+00]
# Presolve removed 355 rows and 194 columns
# Presolve time: 0.01s
# Presolved: 87 rows, 135 columns, 561 nonzeros
# Variable types: 0 continuous, 135 integer (115 binary)
# Found heuristic solution: objective -12.0000000
# Found heuristic solution: objective 4.0000000
# Found heuristic solution: objective 7.0000000
#
# Root relaxation: objective 6.900000e+01, 96 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   69.00000    0   25    7.00000   69.00000   886%     -    0s
# H    0     0                      27.0000000   69.00000   156%     -    0s
# H    0     0                      45.0000000   69.00000  53.3%     -    0s
# H    0     0                      48.0000000   69.00000  43.8%     -    0s
# H    0     0                      56.0000000   64.33334  14.9%     -    0s
#      0     0   64.33334    0   38   56.00000   64.33334  14.9%     -    0s
#      0     0   63.84211    0   38   56.00000   63.84211  14.0%     -    0s
#      0     0   62.50000    0   45   56.00000   62.50000  11.6%     -    0s
#      0     0   62.50000    0   54   56.00000   62.50000  11.6%     -    0s
#      0     0   62.50000    0   56   56.00000   62.50000  11.6%     -    0s
#      0     0   62.50000    0   42   56.00000   62.50000  11.6%     -    0s
#      0     2   62.50000    0   38   56.00000   62.50000  11.6%     -    0s
# *    3     6               2      62.0000000   62.50000  0.81%  39.0    0s
#
# Cutting planes:
#   Gomory: 3
#   Cover: 9
#   Clique: 3
#   MIR: 4
#   Flow cover: 2
#   GUB cover: 2
#   Zero half: 2
#   RLT: 1
#   Relax-and-lift: 1
#
# Explored 7 nodes (551 simplex iterations) in 0.14 seconds (0.02 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 8: 62 56 48 ... -12
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 6.200000000000e+01, best bound 6.200000000000e+01, gap 0.0000%
# 3
# 2
# 62.0
# ____
# Gurobi Optimizer version 10.0.0 build v10.0.0rc2 (win64)
#
# CPU model: Intel(R) Core(TM) i7-1065G7 CPU @ 1.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 442 rows, 329 columns and 1916 nonzeros
# Model fingerprint: 0x72f7ec9a
# Model has 41 general constraints
# Variable types: 0 continuous, 329 integer (270 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 5e+00]
#   Objective range  [3e+00, 2e+01]
#   Bounds range     [1e+00, 1e+02]
#   RHS range        [1e+00, 5e+00]
#   GenCon const rng [1e+00, 1e+00]
# Presolve removed 355 rows and 194 columns
# Presolve time: 0.01s
# Presolved: 87 rows, 135 columns, 561 nonzeros
# Variable types: 0 continuous, 135 integer (115 binary)
# Found heuristic solution: objective 4.0000000
#
# Root relaxation: objective 6.900000e+01, 106 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   69.00000    0    3    4.00000   69.00000  1625%     -    0s
# H    0     0                      59.0000000   69.00000  16.9%     -    0s
# H    0     0                      64.0000000   69.00000  7.81%     -    0s
#      0     0     cutoff    0        64.00000   64.00000  0.00%     -    0s
#
# Cutting planes:
#   RLT: 2
#
# Explored 1 nodes (253 simplex iterations) in 0.04 seconds (0.01 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 64 59 4
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 6.400000000000e+01, best bound 6.400000000000e+01, gap 0.0000%
# 3
# 3
# 64.0
# ____
# Gurobi Optimizer version 10.0.0 build v10.0.0rc2 (win64)
#
# CPU model: Intel(R) Core(TM) i7-1065G7 CPU @ 1.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 442 rows, 329 columns and 1916 nonzeros
# Model fingerprint: 0xfa697922
# Model has 41 general constraints
# Variable types: 0 continuous, 329 integer (270 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 5e+00]
#   Objective range  [3e+00, 2e+01]
#   Bounds range     [1e+00, 1e+02]
#   RHS range        [1e+00, 5e+00]
#   GenCon const rng [1e+00, 1e+00]
# Presolve removed 357 rows and 196 columns
# Presolve time: 0.01s
# Presolved: 85 rows, 133 columns, 557 nonzeros
# Variable types: 0 continuous, 133 integer (115 binary)
# Found heuristic solution: objective 4.0000000
#
# Root relaxation: objective 6.900000e+01, 107 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   69.00000    0    3    4.00000   69.00000  1625%     -    0s
# H    0     0                      59.0000000   69.00000  16.9%     -    0s
#      0     0   64.86667    0   37   59.00000   64.86667  9.94%     -    0s
# H    0     0                      64.0000000   64.86667  1.35%     -    0s
#      0     0   64.86667    0   37   64.00000   64.86667  1.35%     -    0s
#
# Cutting planes:
#   Gomory: 1
#   Cover: 1
#
# Explored 1 nodes (157 simplex iterations) in 0.04 seconds (0.01 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 64 59 4
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 6.400000000000e+01, best bound 6.400000000000e+01, gap 0.0000%
# 3
# 4
# 64.0
# ____
# Gurobi Optimizer version 10.0.0 build v10.0.0rc2 (win64)
#
# CPU model: Intel(R) Core(TM) i7-1065G7 CPU @ 1.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 442 rows, 329 columns and 1916 nonzeros
# Model fingerprint: 0xc46fe826
# Model has 41 general constraints
# Variable types: 0 continuous, 329 integer (270 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 5e+00]
#   Objective range  [3e+00, 2e+01]
#   Bounds range     [1e+00, 1e+02]
#   RHS range        [1e+00, 5e+00]
#   GenCon const rng [1e+00, 1e+00]
# Presolve removed 367 rows and 208 columns
# Presolve time: 0.01s
# Presolved: 75 rows, 121 columns, 546 nonzeros
# Variable types: 0 continuous, 121 integer (106 binary)
# Found heuristic solution: objective 4.0000000
#
# Root relaxation: objective 5.262446e+01, 137 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   52.62446    0   45    4.00000   52.62446  1216%     -    0s
# H    0     0                      14.0000000   52.62446   276%     -    0s
# H    0     0                      34.0000000   52.62446  54.8%     -    0s
# H    0     0                      36.0000000   45.50337  26.4%     -    0s
#      0     0   36.00000    0   55   36.00000   36.00000  0.00%     -    0s
#
# Cutting planes:
#   Gomory: 21
#   Cover: 11
#   Implied bound: 3
#   Clique: 47
#   MIR: 5
#   GUB cover: 3
#   Zero half: 5
#   RLT: 7
#   Relax-and-lift: 2
#
# Explored 1 nodes (230 simplex iterations) in 0.06 seconds (0.01 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 4: 36 34 14 4
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.600000000000e+01, best bound 3.600000000000e+01, gap 0.0000%
# 4
# 1
# 36.0
# ____
# Gurobi Optimizer version 10.0.0 build v10.0.0rc2 (win64)
#
# CPU model: Intel(R) Core(TM) i7-1065G7 CPU @ 1.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 442 rows, 329 columns and 1916 nonzeros
# Model fingerprint: 0x43c7cc09
# Model has 41 general constraints
# Variable types: 0 continuous, 329 integer (270 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 5e+00]
#   Objective range  [3e+00, 2e+01]
#   Bounds range     [1e+00, 1e+02]
#   RHS range        [1e+00, 5e+00]
#   GenCon const rng [1e+00, 1e+00]
# Presolve removed 359 rows and 195 columns
# Presolve time: 0.00s
# Presolved: 83 rows, 134 columns, 548 nonzeros
# Variable types: 0 continuous, 134 integer (114 binary)
# Found heuristic solution: objective -12.0000000
# Found heuristic solution: objective 4.0000000
#
# Root relaxation: objective 6.900000e+01, 102 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   69.00000    0   15    4.00000   69.00000  1625%     -    0s
# H    0     0                      24.0000000   69.00000   188%     -    0s
# H    0     0                      55.0000000   69.00000  25.5%     -    0s
#      0     0   63.22729    0   42   55.00000   63.22729  15.0%     -    0s
# H    0     0                      56.0000000   63.22729  12.9%     -    0s
#      0     0   61.00000    0   42   56.00000   61.00000  8.93%     -    0s
#      0     0   61.00000    0   53   56.00000   61.00000  8.93%     -    0s
# H    0     0                      58.0000000   61.00000  5.17%     -    0s
#      0     0   61.00000    0   56   58.00000   61.00000  5.17%     -    0s
#      0     0   61.00000    0   58   58.00000   61.00000  5.17%     -    0s
#      0     0   60.50000    0   61   58.00000   60.50000  4.31%     -    0s
#      0     0   60.50000    0   57   58.00000   60.50000  4.31%     -    0s
#      0     0   60.50000    0   59   58.00000   60.50000  4.31%     -    0s
# H    0     0                      59.0000000   60.50000  2.54%     -    0s
#
# Cutting planes:
#   Gomory: 3
#   Cover: 13
#   Clique: 4
#   MIR: 4
#   GUB cover: 3
#   Inf proof: 1
#   Mod-K: 1
#   RLT: 2
#   Relax-and-lift: 5
#
# Explored 1 nodes (270 simplex iterations) in 0.10 seconds (0.01 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 7: 59 58 56 ... -12
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.900000000000e+01, best bound 5.900000000000e+01, gap 0.0000%
# 4
# 2
# 59.0
# ____
# Gurobi Optimizer version 10.0.0 build v10.0.0rc2 (win64)
#
# CPU model: Intel(R) Core(TM) i7-1065G7 CPU @ 1.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 442 rows, 329 columns and 1916 nonzeros
# Model fingerprint: 0xcc8ed551
# Model has 41 general constraints
# Variable types: 0 continuous, 329 integer (270 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 5e+00]
#   Objective range  [3e+00, 2e+01]
#   Bounds range     [1e+00, 1e+02]
#   RHS range        [1e+00, 5e+00]
#   GenCon const rng [1e+00, 1e+00]
# Presolve removed 359 rows and 195 columns
# Presolve time: 0.01s
# Presolved: 83 rows, 134 columns, 548 nonzeros
# Variable types: 0 continuous, 134 integer (114 binary)
# Found heuristic solution: objective 4.0000000
#
# Root relaxation: objective 6.900000e+01, 86 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   69.00000    0    3    4.00000   69.00000  1625%     -    0s
# H    0     0                      59.0000000   69.00000  16.9%     -    0s
# H    0     0                      61.0000000   69.00000  13.1%     -    0s
#      0     0   69.00000    0    9   61.00000   69.00000  13.1%     -    0s
#      0     0   64.00000    0    4   61.00000   64.00000  4.92%     -    0s
#      0     0   64.00000    0    4   61.00000   64.00000  4.92%     -    0s
# H    0     0                      64.0000000   64.00000  0.00%     -    0s
#      0     0   64.00000    0   10   64.00000   64.00000  0.00%     -    0s
#
# Cutting planes:
#   Gomory: 1
#   Cover: 1
#   MIR: 1
#   RLT: 3
#   Relax-and-lift: 1
#
# Explored 1 nodes (240 simplex iterations) in 0.10 seconds (0.01 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 4: 64 61 59 4
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 6.400000000000e+01, best bound 6.400000000000e+01, gap 0.0000%
# 4
# 3
# 64.0
# ____
# Gurobi Optimizer version 10.0.0 build v10.0.0rc2 (win64)
#
# CPU model: Intel(R) Core(TM) i7-1065G7 CPU @ 1.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 442 rows, 329 columns and 1916 nonzeros
# Model fingerprint: 0xd68310f9
# Model has 41 general constraints
# Variable types: 0 continuous, 329 integer (270 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 5e+00]
#   Objective range  [3e+00, 2e+01]
#   Bounds range     [1e+00, 1e+02]
#   RHS range        [1e+00, 5e+00]
#   GenCon const rng [1e+00, 1e+00]
# Presolve removed 361 rows and 197 columns
# Presolve time: 0.01s
# Presolved: 81 rows, 132 columns, 545 nonzeros
# Variable types: 0 continuous, 132 integer (114 binary)
# Found heuristic solution: objective 4.0000000
#
# Root relaxation: objective 6.900000e+01, 61 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   69.00000    0    5    4.00000   69.00000  1625%     -    0s
# H    0     0                      59.0000000   69.00000  16.9%     -    0s
# H    0     0                      64.0000000   69.00000  7.81%     -    0s
#
# Cutting planes:
#   Gomory: 1
#
# Explored 1 nodes (61 simplex iterations) in 0.05 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 64 59 4
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 6.400000000000e+01, best bound 6.400000000000e+01, gap 0.0000%
# 4
# 4
# 64.0
# ____

# %%
    plot_3D(X_grid,Y_grid,grid)
